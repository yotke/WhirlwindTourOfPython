# %% [markdown]
# # Working with files in Python

# %% [markdown]
# The following is inspired by https://www.programiz.com/python-programming/file-operation

# %% [markdown]
# A file is a container in computer storage devices used for storing data.
#
# When we want to read from or write to a file, we need to open it first. When we are done, it needs to be closed so that the resources that are tied with the file are freed.
#
# Hence, in Python, a file operation takes place in the following order:
#
# * Open a file
# * Read or write (perform operation)
# * Close the file

# %% [markdown]
# ## Opening Files in Python

# %% [markdown]
# In Python, we use the `open()` method to open files.
#
# To demonstrate how we open files in Python, let's use the `test.text` file under the `data` folder:

# %% [markdown]
# ![](fig/test.png)

# %% [markdown]
# Now, let's try to open data from this file using the `open()` function:

# %%
# open file in current directory
file1 = open("data/test.txt")

# %% [markdown]
# Here, we have created a file object named file1. This object can be used to work with files and directories.
#
# By default, the files are open in read mode (cannot be modified). The code above is equivalent to

# %%
file1 = open("data/test.txt", "r")

# %% [markdown]
# Here, we have explicitly specified the mode by passing the `"r"` argument which means file is opened for reading.

# %% [markdown]
# **Different Modes to Open a File in Python:**

# %% [markdown]
# <div class="table-responsive">
# 	<table><tbody><tr><th>Mode</th>
# 				<th>Description</th>
# 			</tr><tr><td><code>r</code></td>
# 				<td>Open a file for reading. (default)</td>
# 			</tr><tr><td><code>w</code></td>
# 				<td>Open a file for writing. Creates a new file if it does not exist or truncates the file if it exists.</td>
# 			</tr><tr><td><code>x</code></td>
# 				<td>Open a file for exclusive creation. If the file already exists, the operation fails.</td>
# 			</tr><tr><td><code>a</code></td>
# 				<td>Open a file for appending at the end of the file without truncating it. Creates a new file if it does not exist.</td>
# 			</tr><tr><td><code>t</code></td>
# 				<td>Open in text mode. (default)</td>
# 			</tr><tr><td><code>b</code></td>
# 				<td>Open in binary mode.</td>
# 			</tr><tr><td><code>+</code></td>
# 				<td>Open a file for updating (reading and writing)</td>
# 			</tr></tbody></table></div>

# %% [markdown]
# Here's few simple examples of how to open a file in different modes,

# %% [markdown]
# ```python
# file1 = open("file_name.txt")      # equivalent to 'r' or 'rt'
# file1 = open("file_name",'w')  # write in text mode
# file1 = open("img.bmp",'r+b') # read and write in binary mode
# ```

# %% [markdown]
# ## Reading Files in Python

# %% [markdown]
# After we open a file, we use the `read()` method to read its contents. For example:

# %%
# open a file
file1 = open("data/test.txt", "r")

# read the file
read_content = file1.read()
print(read_content)
# Out:
# This is a test file
# This is the second row in the file
# And this is the third

# %% [markdown]
# Another option is to read the file line by line:

# %%
file1 = open("data/test.txt", "r")
file1.readline()
# Out:
# 'This is a test file\n'

# %% [markdown]
# To iterate over all lines, use the `.readlines()` method:

# %%
file1 = open("data/test.txt", "r")
for l in file1.readlines():
    print(l)
# Out:
# This is a test file
#
# This is the second row in the file
#
# And this is the third

# %% [markdown]
# ## Closing Files in Python

# %% [markdown]
# When we are done with performing operations on the file, we need to properly close the file.
# Closing a file will free up the resources that were tied with the file. It is done using the `close()` method in Python. For example,

# %%
# open a file
file1 = open("data/test.txt", "r")

# read the file
read_content = file1.read()
print(read_content)

# close the file
file1.close()
# Out:
# This is a test file
# This is the second row in the file
# And this is the third

# %% [markdown]
# After we perform file operation, we should always close the file; it's a good programming practice.

# %% [markdown]
# ### Exception Handling in Files

# %% [markdown]
# If an exception occurs when we are performing some operation with the file, the code exits without closing the file. A safer way is to use a try...finally block.
#
# Let's see an example:

# %%
try:
    file1 = open("data/test.txt", "r")
    read_content = file1.read()
    print(read_content)

finally:
    # close the file
    file1.close()
# Out:
# This is a test file
# This is the second row in the file
# And this is the third

# %% [markdown]
# ### Use of with...open Syntax

# %% [markdown]
# In Python, we can use the `with...open` syntax to automatically close the file. For example,

# %%
with open("data/test.txt", "r") as file1:
    read_content = file1.read()
    print(read_content)
# Out:
# This is a test file
# This is the second row in the file
# And this is the third

# %% [markdown]
# ## Writing to Files in Python

# %% [markdown]
# There are two things we need to remember while writing to a file.
#
# * If we try to open a file that doesn't exist, a new file is created.
# * If a file already exists, its content is erased, and new content is added to the file.
#
# In order to write into a file in Python, we need to open it in write mode by passing `"w"` to the `open()` method as a second argument.
#
# Suppose, we don't have a file named test2.txt. Let's see what happens if we write contents to the test2.txt file.

# %%
import os
os.listdir('data')
# Out:
# ['test.txt', '.ipynb_checkpoints']

# %%
with open('data/test2.txt', 'w') as file2:
    # write contents to the test2.txt file
    file2.write('Programming is Fun.')
    file2.write('Programiz for beginners')

# %%
import os
os.listdir('data')
# Out:
# ['test2.txt', 'test.txt', '.ipynb_checkpoints']

# %% [markdown]
# ## The OS module

# %% [markdown]
# See the [official documentation](https://docs.python.org/3/tutorial/stdlib.html) for further info

# %% [markdown]
# The `os` module provides dozens of functions for interacting with the operating system:

# %%
import os

# %%
print(os.getcwd())      # Return the current working directory
# Out:
# /Users/idodavid

# %%
os.chdir('/tmp')   # Change current working directory
os.listdir()
# Out:
# ['msu-target-YYALh84j',
#  'fseventsd-uuid',
#  'tmp-mount-yS4lqO',
#  'com.wacom.UpdateHelper.se.log',
#  'drivefs_ipc.501_shell',
#  'com.google.Keystone',
#  'drivefs_ipc.501',
#  'powerlog',
#  'Sublime Text.356084e074372f17d3b544fa9cfad0b6.2026e4dc6c31ee665ae8bbc8e12101e7.sock',
#  'com.apple.launchd.NQIdCVQGfk',
#  'tmp-mount-HVcVcY',
#  'com.wacom.UpdateHelper.so.log']

# %%
os.system('mkdir today')   # Run the command mkdir in the system shell
os.listdir()
# Out:
# ['msu-target-YYALh84j',
#  'fseventsd-uuid',
#  'tmp-mount-yS4lqO',
#  'com.wacom.UpdateHelper.se.log',
#  'drivefs_ipc.501_shell',
#  'com.google.Keystone',
#  'today',
#  'drivefs_ipc.501',
#  'powerlog',
#  'Sublime Text.356084e074372f17d3b544fa9cfad0b6.2026e4dc6c31ee665ae8bbc8e12101e7.sock',
#  'com.apple.launchd.NQIdCVQGfk',
#  'tmp-mount-HVcVcY',
#  'com.wacom.UpdateHelper.so.log']

# %%
user_dir = os.path.expanduser("~")
os.chdir(user_dir)
os.getcwd()
# Out:
# '/Users/idodavid'

# %% [markdown]
# Be sure to use the `import os` style instead of `from os import *`. This will keep `os.open()` from shadowing the built-in `open()` function which operates much differently.
#
# The built-in `dir()` and `help()` functions are useful as interactive aids for working with large modules like `os`:

# %%
dir(os)[:20]
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE']

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/os
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
# ...

# %% [markdown]
# In data science, we will write and read many data files, such as CSV, TSV, JSON, and pickle files. Thus we will make extensive use of `path` submodule in `os`:

# %% [markdown]
# * `os.path.join()` - join one or more path components intelligently
# * `os.path.basename(path)` - Return the base name of pathname path.
# * `os.path.dirname` - Return the directory name of pathname path.
# * `os.path.exists(path)` - Return True if path refers to an existing path or an open file descriptor.

# %%
path_start = 'Start/of/path'
path_continue = 'and/rest/of/path.txt'
full_path = os.path.join(path_start, path_continue)
full_path
# Out:
# 'Start/of/path/and/rest/of/path.txt'

# %%
print(os.path.dirname(full_path))
print(os.path.basename(full_path))
# Out:
# Start/of/path/and/rest/of
# path.txt

# %% [markdown]
# ## The shutil module

# %%
import shutil

# %% [markdown]
# For daily file and directory management tasks, the [shutil module](https://docs.python.org/3/library/shutil.html#module-shutil) provides a higher level interface that is easier to use. In particular, functions are provided which support file copying and removal. For operations on individual files, see also the os module.

# %% [markdown]
# * `shutil.copy(src, dst)¶` - Copies the file src to the file or directory dst. src and dst should be path-like objects or strings.
# * `shutil.copytree(src, dst)` - Recursively copy an entire directory tree rooted at src to a directory named dst and return the destination directory.
# * `shutil.move(src, dst)` - Recursively move a file or directory (src) to another location (dst) and return the destination.
# * `shutil.rmtree(path)` - Delete an entire directory tree; path must point to a directory

# %% [markdown]
# ## The glob module

# %%
import glob

# %% [markdown]
# * `glob.glob(pathname, *)` - Return a possibly empty list of path names that match pathname, which must be a string containing a path specification.

# %%
os.getcwd()
# Out:
# '/Users/idodavid'

# %%
course_path = os.path.join(os.getcwd(), 'dev/WhirlwindTourOfPython/')
glob.glob(course_path + '*.ipynb')
# Out:
# ['/Users/idodavid/dev/WhirlwindTourOfPython/17-Preview-of-Data-Science-Tools.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/12-Generators.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/02-Basic-Python-Syntax.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/00-Introduction.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/04-Semantics-Operators.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/11-List-Comprehensions.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/16-Working with files.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/15-Classes and Object oriented design.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/03-Semantics-Variables.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/14-Strings-and-Regular-Expressions.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/09-Errors-and-Exceptions.ipynb',
#  '/Users/idodavid/dev/WhirlwindTourOfPython/08-Defining-Functions.ipynb',
# ...

# %% [markdown]
# ## The pickle module

# %% [markdown]
# Python pickle module is used for serializing and de-serializing a Python object structure. Any object in Python can be pickled so that it can be saved on disk. What pickle does is that it “serializes” the object first before writing it to file. Pickling is a way to convert a python object (list, dict, etc.) into a character stream. The idea is that this character stream contains all the information necessary to reconstruct the object in another python script.

# %%
import pickle

# %% [markdown]
# Let's try to define a dictionary, save it to disk, and loading it from disk:

# %%
d = {'name': 'itzik',
     'age': 33, 
     'favorite_color': 'yellow'}

# %% [markdown]
# Let's construct the path to the pickeld file;

# %%
user_dir = os.path.expanduser("~")
repo_dir = os.path.join(user_dir, 'dev/WhirlwindTourOfPython/')
pickle_file_path = os.path.join(repo_dir, 'data/pickled_dict.pkl')
pickle_file_path
# Out:
# '/Users/idodavid/dev/WhirlwindTourOfPython/data/pickled_dict.pkl'

# %% [markdown]
# Now let's open the file descriptor and dump the dictionary to it:

# %%
with open(pickle_file_path, 'wb') as f:
    pickle.dump(d, f)

# %% [markdown]
# You can verify that a new file was created. Now let's load the dict from the new file:

# %%
with open(pickle_file_path, 'rb') as f:
    loaded_d = pickle.load(f)   
print(loaded_d)
# Out:
# {'name': 'itzik', 'age': 33, 'favorite_color': 'yellow'}
